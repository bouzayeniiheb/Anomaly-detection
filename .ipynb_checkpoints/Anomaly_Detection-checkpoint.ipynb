# %% [markdown]
# ## Hourly Time Series Forecasting
# In this notebook we will forecast hourly energy use.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime
datetime
import os
import glob
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Here,We concatenate the csv files containing the data into one csv file titled 'combined_csv'

# %%
path = r'C:\Users\21699\Desktop\myapp\ml_research\Anomaly_Detection\Data_set\FRP #2' 
all_files = glob.glob(path + "/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename,dtype={'Unnamed: 1=':np.float64})
    df1 = df.iloc[:,0:2]
    print(filename,df.shape)
    li.append(df1)

frame = pd.concat(li, axis=0, ignore_index=False)
#frame.to_csv( "combined_csv.csv", index=False )
# Out:
# C:\Users\21699\Desktop\myapp\ml_research\Anomaly_Detection\Data_set\FRP #2\FRP2_HVAC_30s-a.csv (78424, 78)
# C:\Users\21699\Desktop\myapp\ml_research\Anomaly_Detection\Data_set\FRP #2\FRP2_HVAC_30s-b.csv (40327, 78)

# %%
frame.head()

# %%
frame=frame.drop(frame.index[0])

# %%
frame=frame.drop(frame.index[0])

# %%
frame=frame.drop(frame.index[0])

# %%
frame=frame.rename(columns={"TOA5": "Date", "Unnamed: 1": "Energy"})

# %%
#frame.to_csv( "combined.csv", index=False )

# %%
frame.head()

# %%
frame.drop_duplicates(subset='Date', keep='first', inplace=True)

# %%
df = pd.read_csv('combined.csv',dtype={'Energy':np.float64})
df.drop_duplicates(subset='Date', keep='first', inplace=True)
df1=df.reset_index()
del df1['index']
df1.head()

# %%
print(type(df1.Energy.values[0]))
print(type(df1.Date.values[0]))
# Out:
# <class 'numpy.float64'>
# <class 'str'>

# %%
df1['Date'] = pd.to_datetime(df1['Date'],errors='coerce')
print (df1['Date'].dtypes)
# Out:
# datetime64[ns]

# %%
df1.head()
# Out:
#                  Date    Energy
# 0 2016-03-04 17:28:00  9279.285
# 1 2016-03-04 17:29:00  9002.292
# 2 2016-03-04 17:30:00  8933.044
# 3 2016-03-04 17:31:00  8863.795
# 4 2016-03-04 17:32:00  8863.795

# %%
df11=df1.loc[0:176079]
df12=df1.loc[176080:277275]
df13=df1.loc[277276:488661]
df14=df1.loc[488662:528119]
df15=df1.loc[528120:]

# %%
df11= df11.set_index('Date')
df12=df12.set_index('Date')
df13=df13.set_index('Date')
df14=df14.set_index('Date')
df15=df15.set_index('Date')

# %%
print(df11.index)
print(df12.index)
print(df13.index)
print(df14.index)
df15.index
# Out:
# RangeIndex(start=0, stop=176080, step=1)
# RangeIndex(start=176080, stop=277276, step=1)
# RangeIndex(start=277276, stop=488662, step=1)
# RangeIndex(start=488662, stop=528120, step=1)
# RangeIndex(start=528120, stop=588508, step=1)

# %%
df11r = df11.resample("30T",base=28).ffill()
df12r = df12.resample("30T",base=16).ffill()
df13r = df13.resample("30T",base=18).bfill()
df14r = df14.resample("30T",base=15).ffill()
df15r = df15.resample("30T",base=24).ffill()
df11r.plot(subplots=True,figsize=(30,10), linewidth=5, fontsize=30)
df12r.plot(subplots=True,figsize=(30,10), linewidth=5, fontsize=30)
df13r.plot(subplots=True,figsize=(30,10), linewidth=5, fontsize=30)
df14r.plot(subplots=True,figsize=(30,10), linewidth=5, fontsize=30)
df15r.plot(subplots=True,figsize=(30,10), linewidth=5, fontsize=30)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002DA6F11A940>],
#       dtype=object)

# %%
import matplotlib.pyplot as plt
import datetime
import numpy as np

x = np.array([datetime.datetime(2013, 9, 28, i, 0) for i in range(24)])
y = np.random.randint(100, size=x.shape)

plt.plot(x,y)
plt.show()

# %%
df1r=pd.concat([df11r,df12r,df13r,df14r,df15r],axis=0)
df11r.head()
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df1r.plot(subplots=True,figsize=(30,10), linewidth=5, fontsize=30)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002DA38BDBEB8>],
#       dtype=object)

# %%
df1 = df1.set_index('Date')
print(df1.index)
# Out:
# DatetimeIndex(['2016-03-04 17:28:00', '2016-03-04 17:29:00',
#                '2016-03-04 17:30:00', '2016-03-04 17:31:00',
#                '2016-03-04 17:32:00', '2016-03-04 17:33:00',
#                '2016-03-04 17:34:00', '2016-03-04 17:35:00',
#                '2016-03-04 17:36:00', '2016-03-04 17:37:00',
#                ...
#                '2016-12-14 23:52:00', '2016-12-14 23:53:00',
#                '2016-12-14 23:54:00', '2016-12-14 23:55:00',
#                '2016-12-14 23:56:00', '2016-12-14 23:57:00',
#                '2016-12-14 23:58:00', '2016-12-14 23:59:00',
#                '2016-12-15 00:00:00', '2016-12-15 00:01:00'],
#               dtype='datetime64[ns]', name='Date', length=588508, freq=None)

# %%
df1r_train= df1r.iloc[:10706]
df1r_dev=df1r.iloc[10707:12713]
df1r_test=df1r.iloc[12714:]

# %%
list_datetime=[index for index in df1.index ]

# %%
from datetime import datetime
def check_gap(tol):
 d=[] 
 l={}
 cmpt=0
 for i in range (len(list_datetime)-1):
  s1=list_datetime[i].strftime("%Y-%m-%d %H:%M:%S")
  s2=list_datetime[i+1].strftime("%Y-%m-%d %H:%M:%S")
  FMT= '%Y-%m-%d %H:%M:%S'
  tdelta=datetime.strptime(s2,FMT)-datetime.strptime(s1,FMT)
  if(tdelta.seconds>tol):
        d.append(i)
        d.append(i+1)
        l['Gap '+str(cmpt)]='The Gap period:'+str(tdelta.seconds)+' sec => Start at '+s1+'|'+'End at '+s2+''
        cmpt=cmpt+1
 print('We have '+str(cmpt)+' Gaps!')
 print(l) 
 print(d)
check_gap(3600)
# Out:
# We have 4 Gaps!
# {'Gap 0': 'The Gap period:60150 sec => Start at 2016-05-18 12:33:30|End at 2016-05-23 05:16:00', 'Gap 1': 'The Gap period:17820 sec => Start at 2016-06-27 08:51:30|End at 2016-06-28 13:48:30', 'Gap 2': 'The Gap period:34560 sec => Start at 2016-10-06 00:09:00|End at 2016-10-06 09:45:00', 'Gap 3': 'The Gap period:21540 sec => Start at 2016-11-02 19:25:00|End at 2016-11-03 01:24:00'}
# [176079, 176080, 277275, 277276, 488661, 488662, 528119, 528120]

# %%
df1r.isnull().values.any()
# Out:
# False

# %%
df1r.plot(figsize=(30,10), linewidth=5, fontsize=30)
plt.xlabel('Date', fontsize=30);

# %%
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=True, rc=None)
sns.boxplot(df1r['Energy'],showfliers=False,orient='h',notch=False,color='red')

# %%
df1r.plot(style=['k--', 'bo-', 'r*'], figsize=(20, 10));

# %%
df1 = df1.assign(InterpolateTime=df1.Energy.interpolate(method='time'))

# %%
final_df= df1[['Energy','InterpolateTime']]
final_df.plot(style=['b-.', 'ko', 'r.', 'rx-'], figsize=(20,10));
plt.ylabel('Energy');
plt.legend(loc='upper center', bbox_to_anchor=(0.5, 1.05),
          fancybox=True, shadow=True, ncol=5, prop={'size': 14} );
